# %% [markdown]
# <a href="https://colab.research.google.com/github/ManuelT004/CSC221_Mteja004/blob/main/assignment21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 4.2 Object Identity and Type

# Make a function that performs differently depending on the types of its inputs
# cat(a, b) below will work if you pass in two numbers or two strings
# Use isinstance to detect when you are getting a string and an int and
# automatically convert the int to a string and return the string!

def cat(a, b):
    return a + b

print(cat(3, 5))
print(cat("Hello, ", "World!"))
print(cat("Hello, ", 123))  # FAILS: Should return 'Hello, 123'

# INSERT YOUR CODE HERE

def cat(a, b):
    if isinstance(a, str) and isinstance(b, int):
        b = str(b)
    elif isinstance(a, int) and isinstance(b, str):
        a = str(a)

    return a + b

# Test cases
print(cat(3, 5))              # Output: 8
print(cat("Hello, ", "World!"))  # Output: Hello, World!
print(cat("Hello, ", 123))    # Output: Hello, 123

# Explain the output of the following code
import sys

class EmptyClass:
    def __init__(self):
        print('init')
    def __del__(self):
        print('del')

def print_refcount(x):
    print(sys.getrefcount(x))

f1 = EmptyClass()
print_refcount(f1)
f2 = f1
print_refcount(f1)
f3 = f1
print_refcount(f1)

del f1
print_refcount(f3)
del f2
print_refcount(f3)
del f3

# INSERT YOUR EXPLANATION HERE

f1 = EmptyClass()  # Creates an instance of EmptyClass and prints 'init'
print_refcount(f1)  # Prints the reference count (initially 2: one for f1 and one for the argument in print_refcount)

f2 = f1  # Assigns f1 to f2, increasing the reference count by 1
print_refcount(f1)  # Prints the updated reference count (3: f1, f2, and the argument in print_refcount)
f3 = f1  # Assigns f1 to f3, further increasing the reference count by 1
print_refcount(f1)  # Prints the updated reference count (4: f1, f2, f3, and the argument in print_refcount)

del f1  # Deletes reference f1, reducing the reference count by 1
print_refcount(f3)  # Prints the updated reference count (3: f2, f3, and the argument in print_refcount)
del f2  # Deletes reference f2, further reducing the reference count by 1
print_refcount(f3)  # Prints the updated reference count (2: f3 and the argument in print_refcount)
del f3  # Deletes reference f3, reducing the reference count by 1 and causing the instance to be deleted


init
4
5
6
5
4
del

# Section 4.4, Part 1
# Explain this output. Why does it seem odd?
a = [1, 2, 3]
b = a
b[1] = 99
print(a)
print(b)

# INSERT YOUR EXPLANATION HERE
#b[1] pointing to the same object as a makes it change to the 2nd value of the list to 99

[1, 99, 3]
[1, 99, 3]

# Section 4.4, Part 2
# Explain this output. Why is it from Part 1?
a = [1, 2, 3]
b = a[:]
b[1] = 99
print(a)
print(b)

# INSERT YOUR EXPLANATION HERE
#though it seems a bit weird it rlly makes a lot of sense
#a and b are set to equal different things but are then put to equal each other, so they are both pointiong to the same object'
#b[1] where alone could be set to equal a whole thing on its own, due to being equal to a
#b[1] is equal to the second variable of the list, which turns it into [1, 99, 3]

[1, 2, 3]
[1, 99, 3]

# Section 4.4, Part 3
# Explain this output. Why is it from Part 1?
a = [1, 2, 3]
b = list(a)
b[1] = 99
print(a)
print(b)

# INSERT YOUR EXPLANATION HERE
#b points to list a which is different from a
#so just print b prints the 99 in the 2nd placement

[1, 2, 3]
[1, 99, 3]

# Section 4.4, Part 4
# Now we understand copy vs. reference. What about shallow vs. deep copy?
# Here's a shoolow copy. Why are a and b the same?
a = [1, [100, 101], 3]
b = list(a)
b[1][1] = 900
print(a)
print(b)

# INSERT YOUR EXPLANATION HERE
#due to this being a shallow copy this causes the changes of one list to effect the other
#so ant changes done to the list at all is effecting any and all list tied to this object

[1, [100, 900], 3]
[1, [100, 900], 3]

# Section 4.4, Part 5
# Modify the code from the cell above (repeated here) to perform a deepcopy of a
# Explain how that is different.
import copy

a = [1, [100, 101], 3]
b = copy.deepcopy(a)

b[1][1] = 900

print(a)  # Output: [1, [100, 101], 3]
print(b)  # Output: [1, [100, 900], 3]

# INSERT YOUR EXPLANATION HERE
# this is defferent due to the fact the changes to one wont effect the other
